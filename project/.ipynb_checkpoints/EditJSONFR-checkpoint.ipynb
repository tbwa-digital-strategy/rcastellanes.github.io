# %%
import pandas as pd
import json
import geopandas as gpd

# %%
county = gpd.read_file('france.geojson')

# %%
county.head()
# Out:
#   NUTS_ID  STAT_LEVL_  SHAPE_AREA  SHAPE_LEN  \
# 0   AT111           3    0.080896   1.088912
# 1   AT112           3    0.252917   2.229645
# 2   AT113           3    0.197644   1.952596
# 3   AT121           3    0.430926   2.989854
# 4   AT122           3    0.425235   2.961301
#
#                                             geometry
# 0  POLYGON ((16.64622 47.446597, 16.4337615 47.35...
# 1  POLYGON ((17.1607975 48.006656501, 17.093074 4...
# 2  POLYGON ((16.4337615 47.35291849999999, 16.508...
# 3  POLYGON ((15.507681 48.31959849899999, 15.4224...
# 4  POLYGON ((16.38889149900001 47.88160099700002,...

# %%
maindata = pd.read_csv('francemaindata.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-86507a7b7a33> in <module>()
# ----> 1 maindata = pd.read_csv('francemaindata.csv')
#
# ...

# %%
maindata.head()
# Out:
#    STATE  COUNTY   STNAME  VOLOVERALLFEMALE1112ALL  VOLOVERALLFEMALE1112AA  \
# 0      1       1  Alabama                      426                      80
# 1      1       3  Alabama                     1224                     141
# 2      1       5  Alabama                      157                      88
# 3      1       7  Alabama                      131                      24
# 4      1       9  Alabama                      397                       7
#
#    VOLOVERALLFEMALE1112HISP  VOLOVERALLFEMALE1112OTHER  VOLOVERALLMALE1112ALL  \
# 0                        13                         18                    432
# 1                        71                         62                   1265
# 2                         8                          3                    167
# 3                         3                          2                    152
# 4                        51                         13                    415
#
# ...

# %%
county.STATEFP = pd.Series(county.STATEFP, dtype = 'float64')
county.COUNTYFP = pd.Series(county.COUNTYFP, dtype = 'float64')

# %%
subdata = pd.read_csv('newsubdata.csv')

# %%
subdata.head()
# Out:
#    STATE  COUNTY  VOLNODRSCOREMALE1112  VOLNODRSCOREFEMALE1112  \
# 0      1       1            916.755181              929.538620
# 1      1       3           2899.651985             2886.038595
# 2      1       5            343.826697              350.533330
# 3      1       7            323.489486              275.428191
# 4      1       9            803.884602              844.965311
#
#    VOLNODRSCOREMALE1826  VOLNODRSCOREFEMALE1826  VOLDRSCOREMALE1112  \
# 0            759.701505              744.178758            0.133872
# 1           2471.928066             2404.739402            0.423430
# 2            440.402207              303.586902            0.050208
# 3            365.080991              273.579679            0.047239
# 4            723.885328              673.291192            0.117390
#
#    VOLDRSCOREFEMALE1112  VOLDRSCOREMALE1826  VOLDRSCOREFEMALE1826  \
# 0              0.135739            0.110938              0.108671
# ...

# %%
newdata = pd.merge(county, maindata, how = 'left', left_on = ['STATEFP', 'COUNTYFP'], right_on=['STATE','COUNTY'])
newdata = pd.merge(newdata, subdata, how = 'left', left_on = ['STATEFP', 'COUNTYFP'], right_on=['STATE','COUNTY'])

# %%
newdata.to_file('countymerged.json', driver = 'GeoJSON')
# Out:
# ---------------------------------------------------------------------------
# CPLE_NotSupportedError                    Traceback (most recent call last)
# fiona/ogrext.pyx in fiona.ogrext.WritingSession.start()
#
# fiona/_err.pyx in fiona._err.exc_wrap_pointer()
#
# CPLE_NotSupportedError: GeoJSON driver doesn't support creating a layer on a read-only datasource
#
# During handling of the above exception, another exception occurred:
#
# DriverIOError                             Traceback (most recent call last)
# <ipython-input-15-4c8aea2bab06> in <module>()
# ----> 1 newdata.to_file('countymerged.json', driver = 'GeoJSON')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/geopandas/geodataframe.py in to_file(self, filename, driver, schema, **kwargs)
#     363         """
#     364         from geopandas.io.file import to_file
# --> 365         to_file(self, filename, driver, schema, **kwargs)
#     366
# ...
